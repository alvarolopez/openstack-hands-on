# %% [markdown]
# # Introducción
# OpenStack está basado en diferentes componentes, cada uno ofreciendo una funcionalidad diferente. Aunque todos están relacionados entre sí, es necesario utilizar clientes diferentes para cada uno de ellos. Los componentes fundamentales son los siguientes:
#
# * OpenStack Dashboard (Horizon): Interfaz web.
# * OpenStack Identity (Keystone): Gestiona las identidades de los usuarios.
# * OpenStack Compute (Nova): Gestiona los servidores (instancias): creación, parada, borrado, reinicio, etc. Podemos indicarle que tipo de instancia queremos a través de "flavors" (configuraciones de hardware predefinidas).
# * OpenStack Image (Glance): Gestiona las imágenes de disco en las que se basarán los servidores que arranquemos.
# * OpenStack Volume (Cinder): Gestiona volúmenes (disco) que podemos agregar a un servidor. Estos volúmenes persisten hasta que los borremos explícitamente, por lo que podemos cambiar el servidor al que están agregados.ç
# * OpenStack Networking (Neutron): Gestiona la red de nuestras máquinas. Permite definir topologías complejas.
# * OpenStack Storage (Swift): Permite almacenar ficheros (object/blob) (similar a S3).
#
# Los clientes de Python que existen para cada uno de ellos son:
#
# * `python-openstackclient`: Cliente de línea de comandos general de OpenStack, agrega todos los clientes individuales.
# * `python-keystoneclient`: Librería de Python para interactuar con Keystone.
# * `python-novaclient`: Librería de Python para interactuar con Nova.
# * `python-glanceclient`: Librería de Python para interactuar con Glance.
# * `python-cinderclient`: Librería de Python para interactuar con Cinder.
# * `python-neutronclient`: Librería de Python para interactuar con Neutron.
# * `python-swiftclient`: Librería de Python para interactuar con Swift.
#
# Asimismo, podemos utilizar el SDK de [OpenStack](https://docs.openstack.org/openstacksdk/latest/index.html), el cual nos proporciona un acceso coherente y unificado a ambos tipos de recursos.
#
# Vamos a ver como funcionan ambos y sus diferencias.
#
# # Instalación
#
# Es necesario asegurar que todos los paquetes de OpenStack están instalados, para ello ejecutamos el siguiente comando:
#
#     pip install openstacksdk openstackclient

# %% [markdown]
# # Parámetros globales

# %%
# Es necesario definir el usuario, contraseña y proyecto
# al que queremos acceder
USERNAME = "master20"
PASSWORD = ""
PROJECT_ID = "c725b18d8d0643e7b410dc5a8d9ab554"

# Parámetros de la conexión y de la versión de la API a utilizar
AUTH_URL = "https://api.cloud.ifca.es:5000/v3"
NOVA_VERSION = "2"
DOMAIN = "IFCA"

# %% [markdown]
# # Uso de los clientes nativos de OpenStack

# %% [markdown]
# ## Módulos necesarios

# %%
import time

from keystoneauth1 import loading
from keystoneauth1 import session
from glanceclient import Client as g_client
from neutronclient.v2_0 import client as net_client
from novaclient import client as n_client

# %% [markdown]
# ## Authenticación
# Vamos a utilizar un objeto de sesión que se va a encargar de gestionar la autenticación (por ejemplo gestionando por nosotros la caducidad de las credenciales) en todos los clientes y en las diferentes llamadas a los mismos.

# %%
# Indicamos que queremos utilizar el plugin de "password", ya que
# vamos a utilizar un usuario y contraseña para conectar
loader = loading.get_plugin_loader('password')
auth = loader.load_from_options(auth_url=AUTH_URL,
                                username=USERNAME,
                                password=PASSWORD,
                                project_id=PROJECT_ID,
                                user_domain_name=DOMAIN)

# Creamos un objeto de sesión, para utilizar con todos los clientes
# que vamos a utilizar y no tener que autenticarnos cada vez con 
# cada uno de ellos
sess = session.Session(auth=auth)

# %% [markdown]
# ## Nova
#
# Nova es el componente que se encarga de manejar los servidores (instancias). A él le daremos las ordenes de creación, parada, etc.
#
# Primero creamos el cliente que vamos a utilizar en el resto de la sesión.

# %%
nova = n_client.Client(NOVA_VERSION, session=sess)

# %% [markdown]
# Vamos a ver si hay algo ejecutándose ya:

# %%
servers = nova.servers.list()

# %%
for server in servers:
    print("-" * 90)
    print("Server ID:", server.id)
    print("Server name:", server.name)
# Out:
# ------------------------------------------------------------------------------------------
# Server ID: 95605d58-5479-4552-88d5-f0c50772229f
# Server name: jorgej2
# ------------------------------------------------------------------------------------------
# Server ID: 8814ba5d-013f-4d65-989f-8d734fb99e9d
# Server name: Cabrillo_Hadoop
# ------------------------------------------------------------------------------------------
# Server ID: 55804695-a047-40f0-8c76-d033445f8215
# Server name: master04
# ------------------------------------------------------------------------------------------
# Server ID: ce3ee895-c826-42aa-a30b-0751ec798ded
# Server name: master03
# ------------------------------------------------------------------------------------------
# Server ID: 29921dc0-9848-4daa-96b9-f156fcc7b79b
# Server name: Master02
# ------------------------------------------------------------------------------------------
# Server ID: 428e5bfb-0c83-4c42-9231-6a0c8ba5d6e7
# Server name: Nodo_de_Login

# %% [markdown]
# Vamos a ver todos los flavors a los que tenemos acceso

# %%
flavors = nova.flavors.list(sort_key="name")
for flavor in flavors:
    print("-" * 90)
    print("Flavor ID:", flavor.id)
    print("Flavor:", flavor.name)
    print("RAM:", flavor.ram)
    print("CPUS:", flavor.vcpus)
# Out:
# ------------------------------------------------------------------------------------------
# Flavor ID: 786e7ddc-e0a5-4c6a-b513-795bd1b5c54f
# Flavor: cm4.2xlarge
# RAM: 15000
# CPUS: 8
# ------------------------------------------------------------------------------------------
# Flavor ID: 9beb31e1-0796-4a2e-9d48-8b5f41a44d89
# Flavor: cm4.4xlarge
# RAM: 30000
# CPUS: 16
# ------------------------------------------------------------------------------------------
# Flavor ID: 45d32c56-c2e8-4fed-a254-5e9cf0be62fc
# Flavor: cm4.4xlargeD
# RAM: 30000
# CPUS: 16
# ------------------------------------------------------------------------------------------
# Flavor ID: c765383f-b144-4e90-8819-0cd00cabff67
# Flavor: cm4.8xlarge
# RAM: 60000
# CPUS: 32
# ------------------------------------------------------------------------------------------
# Flavor ID: cd775e27-af09-407b-ab34-fb999ba418bd
# Flavor: cm4.large
# RAM: 3500
# CPUS: 2
# ------------------------------------------------------------------------------------------
# Flavor ID: 3e880029-31a2-418a-8c69-f3330aaa3e96
# Flavor: cm4.xlarge
# RAM: 7500
# CPUS: 4
# ------------------------------------------------------------------------------------------
# Flavor ID: 4
# Flavor: m1.large
# RAM: 7000
# CPUS: 4
# ------------------------------------------------------------------------------------------
# Flavor ID: 3
# Flavor: m1.medium
# RAM: 4000
# CPUS: 2
# ------------------------------------------------------------------------------------------
# Flavor ID: 2
# Flavor: m1.small
# RAM: 2000
# CPUS: 1
# ------------------------------------------------------------------------------------------
# Flavor ID: 1
# Flavor: m1.tiny
# RAM: 512
# CPUS: 1
# ------------------------------------------------------------------------------------------
# Flavor ID: 5
# Flavor: m1.xlarge
# RAM: 14000
# CPUS: 8

# %% [markdown]
# Podemos filtrar por RAM disponible

# %%
flavors_16GB = nova.flavors.list(sort_key="name", min_ram=16000)
for flavor in flavors_16GB:
    print("-" * 90)
    print("Flavor ID:", flavor.id)
    print("Flavor:", flavor.name)
    print("RAM:", flavor.ram)
    print("CPUS:", flavor.vcpus)
# Out:
# ------------------------------------------------------------------------------------------
# Flavor ID: 9beb31e1-0796-4a2e-9d48-8b5f41a44d89
# Flavor: cm4.4xlarge
# RAM: 30000
# CPUS: 16
# ------------------------------------------------------------------------------------------
# Flavor ID: 45d32c56-c2e8-4fed-a254-5e9cf0be62fc
# Flavor: cm4.4xlargeD
# RAM: 30000
# CPUS: 16
# ------------------------------------------------------------------------------------------
# Flavor ID: c765383f-b144-4e90-8819-0cd00cabff67
# Flavor: cm4.8xlarge
# RAM: 60000
# CPUS: 32

# %% [markdown]
# Vamos a utilizar la function `to_dataframe` para mostrar los resultados de una forma más clara en el notebook, guardándolos en un DataFrame de pandas. Esto realmente NO es necesario, pero así podemos ver los resultados de una forma más sencilla y clara.

# %%
import pandas

def to_dataframe(objects):
    df = pandas.DataFrame()

    for obj in objects:
        if hasattr(obj, "to_dict"):
            df = df.append(obj.to_dict(), ignore_index=True)
        else:
            df = df.append(obj, ignore_index=True)

    df = df.set_index("id")
    return df

# %%
to_dataframe(flavors)
# Out:
#                                       OS-FLV-DISABLED:disabled  \
# id
# 786e7ddc-e0a5-4c6a-b513-795bd1b5c54f                       0.0
# 9beb31e1-0796-4a2e-9d48-8b5f41a44d89                       0.0
# 45d32c56-c2e8-4fed-a254-5e9cf0be62fc                       0.0
# c765383f-b144-4e90-8819-0cd00cabff67                       0.0
# cd775e27-af09-407b-ab34-fb999ba418bd                       0.0
# 3e880029-31a2-418a-8c69-f3330aaa3e96                       0.0
# 4                                                          0.0
# 3                                                          0.0
# 2                                                          0.0
# 1                                                          0.0
# 5                                                          0.0
#
#                                       OS-FLV-EXT-DATA:ephemeral   disk  \
# id
# 786e7ddc-e0a5-4c6a-b513-795bd1b5c54f                       30.0   30.0
# 9beb31e1-0796-4a2e-9d48-8b5f41a44d89                       30.0   30.0
# 45d32c56-c2e8-4fed-a254-5e9cf0be62fc                       10.0  250.0
# c765383f-b144-4e90-8819-0cd00cabff67                       30.0   30.0
# cd775e27-af09-407b-ab34-fb999ba418bd                        5.0   20.0
# 3e880029-31a2-418a-8c69-f3330aaa3e96                       20.0   30.0
# 4                                                          40.0   30.0
# 3                                                         100.0   10.0
# 2                                                          20.0   10.0
# 1                                                           0.0    0.0
# 5                                                         100.0   30.0
#
#                                                                                   links  \
# id
# 786e7ddc-e0a5-4c6a-b513-795bd1b5c54f  [{'href': 'https://api.cloud.ifca.es:8774/v2.1...
# 9beb31e1-0796-4a2e-9d48-8b5f41a44d89  [{'href': 'https://api.cloud.ifca.es:8774/v2.1...
# 45d32c56-c2e8-4fed-a254-5e9cf0be62fc  [{'href': 'https://api.cloud.ifca.es:8774/v2.1...
# c765383f-b144-4e90-8819-0cd00cabff67  [{'href': 'https://api.cloud.ifca.es:8774/v2.1...
# cd775e27-af09-407b-ab34-fb999ba418bd  [{'href': 'https://api.cloud.ifca.es:8774/v2.1...
# 3e880029-31a2-418a-8c69-f3330aaa3e96  [{'href': 'https://api.cloud.ifca.es:8774/v2.1...
# 4                                     [{'href': 'https://api.cloud.ifca.es:8774/v2.1...
# 3                                     [{'href': 'https://api.cloud.ifca.es:8774/v2.1...
# 2                                     [{'href': 'https://api.cloud.ifca.es:8774/v2.1...
# 1                                     [{'href': 'https://api.cloud.ifca.es:8774/v2.1...
# 5                                     [{'href': 'https://api.cloud.ifca.es:8774/v2.1...
#
#                                               name  \
# id
# 786e7ddc-e0a5-4c6a-b513-795bd1b5c54f   cm4.2xlarge
# 9beb31e1-0796-4a2e-9d48-8b5f41a44d89   cm4.4xlarge
# 45d32c56-c2e8-4fed-a254-5e9cf0be62fc  cm4.4xlargeD
# c765383f-b144-4e90-8819-0cd00cabff67   cm4.8xlarge
# cd775e27-af09-407b-ab34-fb999ba418bd     cm4.large
# 3e880029-31a2-418a-8c69-f3330aaa3e96    cm4.xlarge
# 4                                         m1.large
# 3                                        m1.medium
# 2                                         m1.small
# 1                                          m1.tiny
# 5                                        m1.xlarge
#
#                                       os-flavor-access:is_public      ram  \
# id
# 786e7ddc-e0a5-4c6a-b513-795bd1b5c54f                         1.0  15000.0
# 9beb31e1-0796-4a2e-9d48-8b5f41a44d89                         1.0  30000.0
# 45d32c56-c2e8-4fed-a254-5e9cf0be62fc                         1.0  30000.0
# c765383f-b144-4e90-8819-0cd00cabff67                         1.0  60000.0
# cd775e27-af09-407b-ab34-fb999ba418bd                         1.0   3500.0
# 3e880029-31a2-418a-8c69-f3330aaa3e96                         1.0   7500.0
# 4                                                            1.0   7000.0
# 3                                                            1.0   4000.0
# 2                                                            1.0   2000.0
# 1                                                            1.0    512.0
# 5                                                            1.0  14000.0
#
#                                       rxtx_factor swap  vcpus
# id
# 786e7ddc-e0a5-4c6a-b513-795bd1b5c54f          1.0         8.0
# 9beb31e1-0796-4a2e-9d48-8b5f41a44d89          1.0        16.0
# 45d32c56-c2e8-4fed-a254-5e9cf0be62fc          1.0        16.0
# c765383f-b144-4e90-8819-0cd00cabff67          1.0        32.0
# cd775e27-af09-407b-ab34-fb999ba418bd          1.0         2.0
# 3e880029-31a2-418a-8c69-f3330aaa3e96          1.0         4.0
# 4                                             1.0         4.0
# 3                                             1.0         2.0
# 2                                             1.0         1.0
# 1                                             1.0         1.0
# 5                                             1.0         8.0

# %% [markdown]
# Vamos a utilizar un flavor medio, por ejemplo `cm4.large` con id `cd775e27-af09-407b-ab34-fb999ba418bd`.

# %%
FLAVOR_ID = "cd775e27-af09-407b-ab34-fb999ba418bd"

# %% [markdown]
# ## Selección de la imagen
# Para seleccionar en que imagen queremos basar nuestra instancia tenemos que interactuar con Glance. Para ello, creamos un objeto cliente que utilizaremos para el resto de llamadas.

# %%
glance = g_client('2', session=sess)

# %%
images = glance.images.list()
images = list(images)

# %%
to_dataframe(images)
# Out:
#                                      architecture  \
# id
# ebdbb5fa-03b3-48e0-822f-69ea86159f52       x86_64
# 259ee15e-0b7c-495e-b521-f25cca3b8a4f       x86_64
# 8ad535fe-754d-41dd-9e71-4ae0a897249b       x86_64
# 29c9370d-9a9c-4361-903f-cf9bb0739c38       x86_64
# 2550696d-1bae-4e6b-bbb7-809c41a8f9c1       x86_64
# ...                                           ...
# 132d1ad0-053c-497d-ab69-0873bf569ee9       x86_64
# 5fb82df2-69e4-4984-9cb9-065582724e66       x86_64
# 51d20ea0-f5b5-4607-828f-ddb3a78fd868       x86_64
# ac58b341-7542-44e0-80da-409cabcd865f       x86_64
# ebe5ab3c-85ce-4205-8c6a-79c90b276cf4          NaN
#
#                                                               checksum  \
# id
# ebdbb5fa-03b3-48e0-822f-69ea86159f52  bb500dbbd2712ac52d1ba8ceed83d6f7
# 259ee15e-0b7c-495e-b521-f25cca3b8a4f  388429afe5aa9c5639a7f9830606ade6
# 8ad535fe-754d-41dd-9e71-4ae0a897249b  8333e99a66839f5f3b5c7dbcdbd60234
# 29c9370d-9a9c-4361-903f-cf9bb0739c38  9c284058d727a6088de13166d13ec6f0
# 2550696d-1bae-4e6b-bbb7-809c41a8f9c1  8dfb67bc48c13b138a2b9e04f0a6917b
# ...                                                                ...
# 132d1ad0-053c-497d-ab69-0873bf569ee9  e9062f63cd5b18455b4dfac874bef886
# 5fb82df2-69e4-4984-9cb9-065582724e66  227c99129a3ab1b60d478ae357906ba6
# 51d20ea0-f5b5-4607-828f-ddb3a78fd868  212b6a881800cad892347073f0de2117
# ac58b341-7542-44e0-80da-409cabcd865f  65e0e8f5a9993e15467841ea7dbbafa2
# ebe5ab3c-85ce-4205-8c6a-79c90b276cf4  e9089dcb79dc7d28fd7a04845b6f22df
#
#                                      container_format            created_at  \
# id
# ebdbb5fa-03b3-48e0-822f-69ea86159f52             bare  2021-03-03T04:00:59Z
# 259ee15e-0b7c-495e-b521-f25cca3b8a4f             bare  2021-02-27T04:00:35Z
# 8ad535fe-754d-41dd-9e71-4ae0a897249b             bare  2021-02-25T04:03:34Z
# 29c9370d-9a9c-4361-903f-cf9bb0739c38             bare  2021-02-25T04:02:30Z
# 2550696d-1bae-4e6b-bbb7-809c41a8f9c1             bare  2021-02-25T04:01:14Z
# ...                                               ...                   ...
# 132d1ad0-053c-497d-ab69-0873bf569ee9             bare  2017-06-14T03:01:20Z
# 5fb82df2-69e4-4984-9cb9-065582724e66             bare  2017-06-14T03:00:28Z
# 51d20ea0-f5b5-4607-828f-ddb3a78fd868             bare  2017-05-16T11:01:58Z
# ac58b341-7542-44e0-80da-409cabcd865f             bare  2017-05-16T11:01:24Z
# ebe5ab3c-85ce-4205-8c6a-79c90b276cf4             bare  2017-03-07T09:56:17Z
#
#                                      disk_format distribution  \
# id
# ebdbb5fa-03b3-48e0-822f-69ea86159f52       qcow2       ubuntu
# 259ee15e-0b7c-495e-b521-f25cca3b8a4f       qcow2       ubuntu
# 8ad535fe-754d-41dd-9e71-4ae0a897249b       qcow2       ubuntu
# 29c9370d-9a9c-4361-903f-cf9bb0739c38       qcow2       ubuntu
# 2550696d-1bae-4e6b-bbb7-809c41a8f9c1       qcow2       ubuntu
# ...                                          ...          ...
# 132d1ad0-053c-497d-ab69-0873bf569ee9       qcow2       centos
# 5fb82df2-69e4-4984-9cb9-065582724e66       qcow2       centos
# 51d20ea0-f5b5-4607-828f-ddb3a78fd868       qcow2       centos
# ac58b341-7542-44e0-80da-409cabcd865f       qcow2       centos
# ebe5ab3c-85ce-4205-8c6a-79c90b276cf4       qcow2          NaN
#
#                                                                                    file  \
# id
# ebdbb5fa-03b3-48e0-822f-69ea86159f52  /v2/images/ebdbb5fa-03b3-48e0-822f-69ea86159f5...
# 259ee15e-0b7c-495e-b521-f25cca3b8a4f  /v2/images/259ee15e-0b7c-495e-b521-f25cca3b8a4...
# 8ad535fe-754d-41dd-9e71-4ae0a897249b  /v2/images/8ad535fe-754d-41dd-9e71-4ae0a897249...
# 29c9370d-9a9c-4361-903f-cf9bb0739c38  /v2/images/29c9370d-9a9c-4361-903f-cf9bb0739c3...
# 2550696d-1bae-4e6b-bbb7-809c41a8f9c1  /v2/images/2550696d-1bae-4e6b-bbb7-809c41a8f9c...
# ...                                                                                 ...
# 132d1ad0-053c-497d-ab69-0873bf569ee9  /v2/images/132d1ad0-053c-497d-ab69-0873bf569ee...
# 5fb82df2-69e4-4984-9cb9-065582724e66  /v2/images/5fb82df2-69e4-4984-9cb9-065582724e6...
# 51d20ea0-f5b5-4607-828f-ddb3a78fd868  /v2/images/51d20ea0-f5b5-4607-828f-ddb3a78fd86...
# ac58b341-7542-44e0-80da-409cabcd865f  /v2/images/ac58b341-7542-44e0-80da-409cabcd865...
# ebe5ab3c-85ce-4205-8c6a-79c90b276cf4  /v2/images/ebe5ab3c-85ce-4205-8c6a-79c90b276cf...
#
#                                       ifca  \
# id
# ebdbb5fa-03b3-48e0-822f-69ea86159f52  true
# 259ee15e-0b7c-495e-b521-f25cca3b8a4f  true
# 8ad535fe-754d-41dd-9e71-4ae0a897249b  true
# 29c9370d-9a9c-4361-903f-cf9bb0739c38  true
# 2550696d-1bae-4e6b-bbb7-809c41a8f9c1  true
# ...                                    ...
# 132d1ad0-053c-497d-ab69-0873bf569ee9  true
# 5fb82df2-69e4-4984-9cb9-065582724e66  true
# 51d20ea0-f5b5-4607-828f-ddb3a78fd868  true
# ac58b341-7542-44e0-80da-409cabcd865f  true
# ebe5ab3c-85ce-4205-8c6a-79c90b276cf4   NaN
#
#                                                                          imgsync.sha256  \
# id
# ebdbb5fa-03b3-48e0-822f-69ea86159f52  fff206730b3b48058713cbe04561b5c6f716e119bfce0f...
# 259ee15e-0b7c-495e-b521-f25cca3b8a4f  e1723087dc43e60bac11c6198a27388297d8454980cecc...
# 8ad535fe-754d-41dd-9e71-4ae0a897249b  6bc857c95dcd51685d1f4f1acb49033fa4e4cc37b771bf...
# 29c9370d-9a9c-4361-903f-cf9bb0739c38  b8956bb51c69356cad1e62de97facd306f2326a97255f1...
# 2550696d-1bae-4e6b-bbb7-809c41a8f9c1  986e137a69d8ec759752750454f19bc12441d1be71c042...
# ...                                                                                 ...
# 132d1ad0-053c-497d-ab69-0873bf569ee9                                                NaN
# 5fb82df2-69e4-4984-9cb9-065582724e66                                                NaN
# 51d20ea0-f5b5-4607-828f-ddb3a78fd868                                                NaN
# ac58b341-7542-44e0-80da-409cabcd865f                                                NaN
# ebe5ab3c-85ce-4205-8c6a-79c90b276cf4                                                NaN
#
#                                       min_disk  ...   source  status tags  \
# id                                              ...
# ebdbb5fa-03b3-48e0-822f-69ea86159f52       0.0  ...  imgsync  active   []
# 259ee15e-0b7c-495e-b521-f25cca3b8a4f       0.0  ...  imgsync  active   []
# 8ad535fe-754d-41dd-9e71-4ae0a897249b       0.0  ...  imgsync  active   []
# 29c9370d-9a9c-4361-903f-cf9bb0739c38       0.0  ...  imgsync  active   []
# 2550696d-1bae-4e6b-bbb7-809c41a8f9c1       0.0  ...  imgsync  active   []
# ...                                        ...  ...      ...     ...  ...
# 132d1ad0-053c-497d-ab69-0873bf569ee9       0.0  ...  imgsync  active   []
# 5fb82df2-69e4-4984-9cb9-065582724e66       0.0  ...  imgsync  active   []
# 51d20ea0-f5b5-4607-828f-ddb3a78fd868       0.0  ...  imgsync  active   []
# ac58b341-7542-44e0-80da-409cabcd865f       0.0  ...  imgsync  active   []
# ebe5ab3c-85ce-4205-8c6a-79c90b276cf4      10.0  ...      NaN  active   []
#
#                                        type            updated_at  version  \
# id
# ebdbb5fa-03b3-48e0-822f-69ea86159f52  Linux  2021-03-03T04:01:07Z    20.04
# 259ee15e-0b7c-495e-b521-f25cca3b8a4f  Linux  2021-02-27T04:00:39Z    16.04
# 8ad535fe-754d-41dd-9e71-4ae0a897249b  Linux  2021-02-25T04:03:41Z    20.04
# 29c9370d-9a9c-4361-903f-cf9bb0739c38  Linux  2021-02-25T04:02:40Z       10
# 2550696d-1bae-4e6b-bbb7-809c41a8f9c1  Linux  2021-02-25T04:01:19Z    18.04
# ...                                     ...                   ...      ...
# 132d1ad0-053c-497d-ab69-0873bf569ee9  Linux  2017-06-14T03:01:41Z        6
# 5fb82df2-69e4-4984-9cb9-065582724e66  Linux  2017-06-14T03:01:11Z        7
# 51d20ea0-f5b5-4607-828f-ddb3a78fd868  Linux  2017-05-16T11:02:12Z        6
# ac58b341-7542-44e0-80da-409cabcd865f  Linux  2017-05-16T11:01:53Z        7
# ebe5ab3c-85ce-4205-8c6a-79c90b276cf4    NaN  2018-05-23T10:23:03Z      NaN
#
#                                      virtual_size visibility  \
# id
# ebdbb5fa-03b3-48e0-822f-69ea86159f52         None     public
# 259ee15e-0b7c-495e-b521-f25cca3b8a4f         None     public
# 8ad535fe-754d-41dd-9e71-4ae0a897249b         None     public
# 29c9370d-9a9c-4361-903f-cf9bb0739c38         None     public
# 2550696d-1bae-4e6b-bbb7-809c41a8f9c1         None     public
# ...                                           ...        ...
# 132d1ad0-053c-497d-ab69-0873bf569ee9         None     public
# 5fb82df2-69e4-4984-9cb9-065582724e66         None     public
# 51d20ea0-f5b5-4607-828f-ddb3a78fd868         None     public
# ac58b341-7542-44e0-80da-409cabcd865f         None     public
# ebe5ab3c-85ce-4205-8c6a-79c90b276cf4         None     public
#
#                                                                          imgsync.sha512  \
# id
# ebdbb5fa-03b3-48e0-822f-69ea86159f52                                                NaN
# 259ee15e-0b7c-495e-b521-f25cca3b8a4f                                                NaN
# 8ad535fe-754d-41dd-9e71-4ae0a897249b                                                NaN
# 29c9370d-9a9c-4361-903f-cf9bb0739c38                                                NaN
# 2550696d-1bae-4e6b-bbb7-809c41a8f9c1                                                NaN
# ...                                                                                 ...
# 132d1ad0-053c-497d-ab69-0873bf569ee9  a2bbe5e576bfc6c33048ea94d9ce97f8c692d3b61120c7...
# 5fb82df2-69e4-4984-9cb9-065582724e66  f935f17dd8de6a6d68aca9465fd10389f17dd7e7b1efe3...
# 51d20ea0-f5b5-4607-828f-ddb3a78fd868  7fe3dd32d88c8e8de12f65b13a7890f1c8e4eaf64e0508...
# ac58b341-7542-44e0-80da-409cabcd865f  1bfe86b4ead9645eee7c334c29cd9d955cc3bd82768c45...
# ebe5ab3c-85ce-4205-8c6a-79c90b276cf4                                                NaN
#
#                                       os_command_line
# id
# ebdbb5fa-03b3-48e0-822f-69ea86159f52              NaN
# 259ee15e-0b7c-495e-b521-f25cca3b8a4f              NaN
# 8ad535fe-754d-41dd-9e71-4ae0a897249b              NaN
# 29c9370d-9a9c-4361-903f-cf9bb0739c38              NaN
# 2550696d-1bae-4e6b-bbb7-809c41a8f9c1              NaN
# ...                                               ...
# 132d1ad0-053c-497d-ab69-0873bf569ee9              NaN
# 5fb82df2-69e4-4984-9cb9-065582724e66              NaN
# 51d20ea0-f5b5-4607-828f-ddb3a78fd868              NaN
# ac58b341-7542-44e0-80da-409cabcd865f              NaN
# ebe5ab3c-85ce-4205-8c6a-79c90b276cf4     console=hvc0
#
# [103 rows x 32 columns]

# %%
# Vamos a listar las imágenes.
for image in images:
    print("-" * 90)
    print("Image ID", image.id)
    print("Image Name", image.name)
# Out:
# ------------------------------------------------------------------------------------------
# Image ID ebdbb5fa-03b3-48e0-822f-69ea86159f52
# Image Name IFCA Ubuntu 20.04 [2021-03-03]
# ------------------------------------------------------------------------------------------
# Image ID 259ee15e-0b7c-495e-b521-f25cca3b8a4f
# Image Name IFCA Ubuntu 16.04 [2021-02-26]
# ------------------------------------------------------------------------------------------
# Image ID 8ad535fe-754d-41dd-9e71-4ae0a897249b
# Image Name IFCA Ubuntu 20.04 [2021-02-25]
# ------------------------------------------------------------------------------------------
# Image ID 29c9370d-9a9c-4361-903f-cf9bb0739c38
# Image Name IFCA Debian 10 [20210224]
# ------------------------------------------------------------------------------------------
# Image ID 2550696d-1bae-4e6b-bbb7-809c41a8f9c1
# Image Name IFCA Ubuntu 18.04 [2021-02-24]
# ------------------------------------------------------------------------------------------
# Image ID ba82af02-691d-439d-9209-809616238287
# Image Name IFCA Ubuntu 16.04 [2021-02-24]
# ------------------------------------------------------------------------------------------
# Image ID 783328b7-c38e-4ce0-80f5-3bfc2bb65269
# Image Name IFCA Ubuntu 20.04 [2021-02-24]
# ------------------------------------------------------------------------------------------
# Image ID e70e439c-283c-4e2b-883c-3448cba97ba3
# Image Name IFCA Ubuntu 18.04 [2021-02-23]
# ------------------------------------------------------------------------------------------
# Image ID b382fe0b-5bf2-40c7-a546-4c1e7b54e0e5
# Image Name IFCA Ubuntu 20.04 [2021-02-23]
# ------------------------------------------------------------------------------------------
# Image ID 7c4ebc1a-26ff-4dd3-aa29-80456111e539
# Image Name IFCA Ubuntu 18.04 [2021-02-22]
# ------------------------------------------------------------------------------------------
# Image ID 3b90908e-26de-474f-9304-56b02bfba6a4
# Image Name IFCA Ubuntu 20.04 [2021-02-20]
# ------------------------------------------------------------------------------------------
# Image ID 6bedc519-6c1e-4009-912e-0755c68bf64d
# Image Name IFCA Debian 10 [20210219]
# ------------------------------------------------------------------------------------------
# Image ID 76e89648-9166-4be9-8f43-0011474dd92c
# Image Name IFCA Debian 9 [20210219]
# ------------------------------------------------------------------------------------------
# Image ID 765f1012-ab52-489d-874a-cf0c11d7038c
# Image Name IFCA Ubuntu 16.04 [2021-02-19]
# ------------------------------------------------------------------------------------------
# Image ID 45fd3506-f300-451c-b639-dc94397627f5
# Image Name IFCA Ubuntu 18.04 [2021-02-18]
# ------------------------------------------------------------------------------------------
# Image ID c8290829-54d6-4b73-9209-55cbf58af469
# Image Name IFCA Ubuntu 20.04 [2021-02-17]
# ------------------------------------------------------------------------------------------
# Image ID 2de65144-0255-4c15-ad73-f921b303e545
# Image Name IFCA Ubuntu 20.04 [2021-02-16]
# ------------------------------------------------------------------------------------------
# Image ID b544fb47-e73d-447a-8141-10ce1f30b95b
# Image Name IFCA Ubuntu 20.04 [2021-02-11]
# ------------------------------------------------------------------------------------------
# Image ID fa38c280-e378-4401-8f8e-867e50850162
# Image Name IFCA Ubuntu 16.04 [2021-02-11]
# ------------------------------------------------------------------------------------------
# Image ID cf2552bd-8ef1-4109-a630-827e25826b32
# Image Name IFCA Ubuntu 18.04 [2021-02-10]
# ------------------------------------------------------------------------------------------
# Image ID 4b4d630d-e895-4e68-8c82-64ffcb7cd135
# Image Name IFCA Ubuntu 20.04 [2021-02-08]
# ------------------------------------------------------------------------------------------
# Image ID b1f6ed8a-a6a9-4e9b-bd04-a5c92e89cd03
# Image Name IFCA CentOS-6-GenericCloud [20141129_01]
# ------------------------------------------------------------------------------------------
# Image ID 6c222849-6248-4b60-8b0f-d8a2d80aef7f
# Image Name IFCA Debian 9 [20210210]
# ------------------------------------------------------------------------------------------
# Image ID f80736f7-5bc0-4575-9d7a-b01ecade63db
# Image Name IFCA Ubuntu 16.04 [2021-02-09]
# ------------------------------------------------------------------------------------------
# Image ID e18cd84c-42f3-4159-afff-9879dc74ba64
# Image Name IFCA Ubuntu 18.04 [2021-02-08]
# ------------------------------------------------------------------------------------------
# Image ID 5a8de577-e947-4569-8b4e-419524b8dd62
# Image Name IFCA Debian 10 [20210206]
# ------------------------------------------------------------------------------------------
# Image ID 76dacee6-ba48-4be8-9ac7-c75ea37d8170
# Image Name IFCA Ubuntu 18.04 [2021-02-03]
# ------------------------------------------------------------------------------------------
# Image ID ac70d1cc-ed87-4e93-a50a-d00e413a8d17
# Image Name IFCA Ubuntu 16.04 [2021-02-03]
# ------------------------------------------------------------------------------------------
# Image ID 38936889-7720-400e-81f6-ef0c7fc1cbd1
# Image Name IFCA Ubuntu 16.04 [2021-02-02]
# ------------------------------------------------------------------------------------------
# Image ID 86debe36-9dc8-40b0-93e7-c2f8a71a4fd3
# Image Name IFCA Ubuntu 14.04 [2019-11-11]
# ------------------------------------------------------------------------------------------
# Image ID 88cba540-b0d2-483c-9d66-539b9b29314d
# Image Name IFCA Ubuntu 18.04 [2021-01-29]
# ------------------------------------------------------------------------------------------
# Image ID 694621ae-4e24-4c33-8cc1-ee84f14a24a7
# Image Name IFCA Ubuntu 16.04 [2021-01-28]
# ------------------------------------------------------------------------------------------
# Image ID 0f5459e9-f842-436d-9c41-0775cca73f51
# Image Name IFCA Debian 10 [20210127]
# ------------------------------------------------------------------------------------------
# Image ID dc6645c6-ebf5-4a25-af73-95467f301368
# Image Name IFCA Debian 9 [20210127]
# ------------------------------------------------------------------------------------------
# Image ID 4274c75c-3950-4490-b670-2ba2bbbd7dc5
# Image Name IFCA Ubuntu 18.04 [2021-01-25]
# ------------------------------------------------------------------------------------------
# Image ID dfc58004-6b5f-4d8c-8391-c6a67e06128f
# Image Name IFCA Ubuntu 18.04 [2021-01-20]
# ------------------------------------------------------------------------------------------
# Image ID 2cf8f98b-1aab-4942-bafc-8b7cfefd4496
# Image Name IFCA Ubuntu 16.04 [2021-01-20]
# ------------------------------------------------------------------------------------------
# Image ID 169661b9-938d-466e-b4c9-10ceb4a76e9b
# Image Name IFCA Ubuntu 16.04 [2021-01-14]
# ------------------------------------------------------------------------------------------
# Image ID 1bf25f1c-0140-430b-b0ff-40aec42a5520
# Image Name IFCA Ubuntu 18.04 [2021-01-13]
# ------------------------------------------------------------------------------------------
# Image ID 88f98340-f48d-4989-9240-e245606b5781
# Image Name IFCA Ubuntu 16.04 [2021-01-13]
# ------------------------------------------------------------------------------------------
# Image ID 179e1450-db45-4137-819f-5b823bee11db
# Image Name IFCA Debian 10 [20210108]
# ------------------------------------------------------------------------------------------
# Image ID 6cb1220c-0e74-4356-97ac-003d25554113
# Image Name IFCA Ubuntu 18.04 [2021-01-08]
# ------------------------------------------------------------------------------------------
# Image ID d95a5fc2-f0fb-47a6-919d-bc00136efb79
# Image Name IFCA Debian 9 [20210106]
# ------------------------------------------------------------------------------------------
# Image ID 907918af-aea9-449b-810e-6ebb10710288
# Image Name IFCA Ubuntu 18.04 [2021-01-07]
# ------------------------------------------------------------------------------------------
# Image ID efcc6f5b-c37d-4a46-a0a9-e1c1223ace28
# Image Name IFCA Ubuntu 18.04 [2021-01-06]
# ------------------------------------------------------------------------------------------
# Image ID 1f1abb9e-502a-411c-b71f-7f62bded791d
# Image Name IFCA Ubuntu 16.04 [2021-01-06]
# ------------------------------------------------------------------------------------------
# Image ID f444d4e1-b8ee-49b0-94cf-512de859f6fa
# Image Name IFCA Ubuntu 18.04 [2021-01-05]
# ------------------------------------------------------------------------------------------
# Image ID fcb1b428-dfa0-41ce-90c1-3531d242b0df
# Image Name IFCA Ubuntu 16.04 [2021-01-05]
# ------------------------------------------------------------------------------------------
# Image ID ca501de8-3307-4b8e-a719-7dd9ff3ec42a
# Image Name IFCA CentOS-7-GenericCloud [2003]
# ------------------------------------------------------------------------------------------
# Image ID 1a94b28b-0859-4119-ad56-969ac9d26ab9
# Image Name IFCA CentOS-8-GenericCloud [2004]
# ------------------------------------------------------------------------------------------
# Image ID b00bdb8b-49bc-40e8-b5fd-c3d94bea7f6d
# Image Name IFCA CentOS-6-GenericCloud [1907]
# ------------------------------------------------------------------------------------------
# Image ID b7bb80ba-7e1c-4a6c-8437-0cc7a6ee13a1
# Image Name IFCA CentOS-7-GenericCloud [1907]
# ------------------------------------------------------------------------------------------
# Image ID 770d0a5e-bd7e-4303-90ba-f1226c4341a2
# Image Name IFCA Debian 9 [20191230]
# ------------------------------------------------------------------------------------------
# Image ID de44a50b-8905-4b18-9d28-b20c88754677
# Image Name IFCA Debian 9 [20191114]
# ------------------------------------------------------------------------------------------
# Image ID 7e63600a-d0a8-41d2-9725-0bca698958ed
# Image Name IFCA Debian 9 [20191015]
# ------------------------------------------------------------------------------------------
# Image ID ad43d2d7-f59d-4c58-8548-3f742e726f90
# Image Name IFCA Debian 9 [20191003]
# ------------------------------------------------------------------------------------------
# Image ID 16cfde89-b172-4be1-b927-03940e655b1f
# Image Name IFCA Debian 9 [20190926]
# ------------------------------------------------------------------------------------------
# Image ID f581b272-8089-43bc-a6bd-63889a6d1072
# Image Name IFCA Debian 9 [20190923]
# ------------------------------------------------------------------------------------------
# Image ID 5b2d7a3d-9e72-47a3-9be0-edfc6f6fd694
# Image Name IFCA Debian 9 [20190909]
# ------------------------------------------------------------------------------------------
# Image ID 4c7f16d1-2ff4-4e05-9f65-d1e68383241e
# Image Name IFCA Debian 9 [20190816]
# ------------------------------------------------------------------------------------------
# Image ID 49e33a1c-9d1e-4925-9f7c-64336b55d159
# Image Name IFCA Debian testing [20190701]
# ------------------------------------------------------------------------------------------
# Image ID 946261ce-fe34-4564-a377-a23138f2c2ae
# Image Name IFCA Debian testing [20190625]
# ------------------------------------------------------------------------------------------
# Image ID 21ae3ece-7ace-4bf8-b3a1-896d6f31dc5a
# Image Name IFCA Debian testing [20190617]
# ------------------------------------------------------------------------------------------
# Image ID e2c7902f-912c-45da-9492-6af3bcb727ae
# Image Name IFCA Debian testing [20190610]
# ------------------------------------------------------------------------------------------
# Image ID a95bb82b-ef14-4707-a48a-bc22095974dc
# Image Name IFCA Debian testing [20190603]
# ------------------------------------------------------------------------------------------
# Image ID ec3b20f8-fa41-4ccb-941a-58f3a4de6005
# Image Name IFCA Debian testing [20190527]
# ------------------------------------------------------------------------------------------
# Image ID 2cbb74d7-2f43-4973-904f-56d5992abf5c
# Image Name IFCA Debian testing [20190520]
# ------------------------------------------------------------------------------------------
# Image ID 47ccdab0-9e3d-4332-8f51-bc1a87ac0de6
# Image Name IFCA Debian testing [20190513]
# ------------------------------------------------------------------------------------------
# Image ID 98241d7d-0684-4906-b20b-99debd2b1a4f
# Image Name IFCA Debian testing [20190506]
# ------------------------------------------------------------------------------------------
# Image ID 5b79749c-1234-4ef0-bdc8-4a1f38efed9a
# Image Name IFCA Debian testing [20190429]
# ------------------------------------------------------------------------------------------
# Image ID 3138a946-4ee6-4464-ab84-982fbcab74b0
# Image Name IFCA Debian testing [20190422]
# ------------------------------------------------------------------------------------------
# Image ID 77c51413-4cb3-4cd0-aaa4-36147bc5d593
# Image Name IFCA Debian testing [20190419]
# ------------------------------------------------------------------------------------------
# Image ID e8e6540c-b7ba-4650-a16c-e2350c4c9d5b
# Image Name IFCA Debian testing [20190416]
# ------------------------------------------------------------------------------------------
# Image ID f93647b1-fd9a-4fc9-882a-e3c80cef3066
# Image Name IFCA Debian testing [20190415]
# ------------------------------------------------------------------------------------------
# Image ID 97c83b1d-065c-46f0-b301-4cee6d2500ed
# Image Name IFCA Debian testing [20190413]
# ------------------------------------------------------------------------------------------
# Image ID 4fe94a5d-9507-48cb-b93d-1beb35ed204f
# Image Name IFCA Debian testing [20190411]
# ------------------------------------------------------------------------------------------
# Image ID 258a9709-9b52-400d-a33c-da5957aada77
# Image Name IFCA Debian testing [20190408]
# ------------------------------------------------------------------------------------------
# Image ID f7db9477-6cfc-4675-9109-7bde9ab4e1fd
# Image Name IFCA Debian testing [20190401]
# ------------------------------------------------------------------------------------------
# Image ID dbb678ec-f5af-4649-9cff-7b93fe62df4f
# Image Name IFCA Debian 8 [20181005]
# ------------------------------------------------------------------------------------------
# Image ID 158a24fc-a9d4-4b7c-a9c9-b6f7f318bca8
# Image Name IFCA Debian 8 [20180929]
# ------------------------------------------------------------------------------------------
# Image ID d2417700-66dc-44e4-ada3-129c0415eff7
# Image Name IFCA Debian 8 [20180831]
# ------------------------------------------------------------------------------------------
# Image ID ac745a0d-a5ef-4e5d-ac28-f397cc8881b9
# Image Name IFCA Debian 8 [20180729]
# ------------------------------------------------------------------------------------------
# Image ID 25aabf9e-1829-4225-bd95-3f594b198c6d
# Image Name IFCA Debian 8 [20180709]
# ------------------------------------------------------------------------------------------
# Image ID 1aa0285e-9c36-4cb2-b79a-bd78665141d3
# Image Name IFCA CentOS-7-GenericCloud [20150628_01]
# ------------------------------------------------------------------------------------------
# Image ID b5fe2b2a-3059-4ceb-8694-16d33197cabf
# Image Name IFCA CentOS-6-GenericCloud [1805]
# ------------------------------------------------------------------------------------------
# Image ID ad01c916-b581-4b4f-b385-66420f5a3c73
# Image Name IFCA CentOS-7-GenericCloud [1805]
# ------------------------------------------------------------------------------------------
# Image ID 63bb873e-7eca-4722-8499-65c39726ea9e
# Image Name IFCA CentOS-6-GenericCloud [1802]
# ------------------------------------------------------------------------------------------
# Image ID 169b537e-bae1-4321-84fa-7f07d3e9dc81
# Image Name IFCA CentOS-7-GenericCloud [1802]
# ------------------------------------------------------------------------------------------
# Image ID b8de2d46-cddf-4c52-a536-85c5a3d032cd
# Image Name IFCA CentOs 7 + MLNX 4.3
# ------------------------------------------------------------------------------------------
# Image ID 0df398e8-5353-46ee-ada3-af16a32bd7a2
# Image Name IFCA CentOS-6-GenericCloud [1711]
# ------------------------------------------------------------------------------------------
# Image ID 4a2b369d-f3bc-4b73-b50a-cbd3687be43e
# Image Name IFCA CentOS-7-GenericCloud [1711]
# ------------------------------------------------------------------------------------------
# Image ID 123e82ea-3707-482d-90ec-260d9829519c
# Image Name IFCA CentOS-6-GenericCloud [1710]
# ------------------------------------------------------------------------------------------
# Image ID c377483a-bc6f-48f1-963d-8ec5cd378bbc
# Image Name IFCA CentOS-7-GenericCloud [1710]
# ------------------------------------------------------------------------------------------
# Image ID 2e370b34-3960-49c1-b1ef-b754b211efe0
# Image Name IFCA CentOS-7-GenericCloud [1708]
# ------------------------------------------------------------------------------------------
# Image ID d5788e59-4309-43f6-9e40-4e7faa525d3e
# Image Name IFCA CentOS-6-GenericCloud [1707]
# ------------------------------------------------------------------------------------------
# Image ID 09a222cc-16b0-405d-aa49-9f59c9c259ae
# Image Name IFCA CentOS-7-GenericCloud [1707]
# ------------------------------------------------------------------------------------------
# Image ID 7aad68ee-32fe-478b-9f13-f31030aecbae
# Image Name IFCA CentOS-6-GenericCloud [1706]
# ------------------------------------------------------------------------------------------
# Image ID 658c7041-a7ba-473f-b55e-e106a877bc64
# Image Name IFCA CentOS-7-GenericCloud [1706]
# ------------------------------------------------------------------------------------------
# Image ID 132d1ad0-053c-497d-ab69-0873bf569ee9
# Image Name IFCA CentOS-6-GenericCloud [1705]
# ------------------------------------------------------------------------------------------
# Image ID 5fb82df2-69e4-4984-9cb9-065582724e66
# Image Name IFCA CentOS-7-GenericCloud [1705]
# ------------------------------------------------------------------------------------------
# Image ID 51d20ea0-f5b5-4607-828f-ddb3a78fd868
# Image Name IFCA CentOS-6-GenericCloud [1704]
# ------------------------------------------------------------------------------------------
# Image ID ac58b341-7542-44e0-80da-409cabcd865f
# Image Name IFCA CentOS-7-GenericCloud [1704]
# ------------------------------------------------------------------------------------------
# Image ID ebe5ab3c-85ce-4205-8c6a-79c90b276cf4
# Image Name UMD verification Scientific Linux 6

# %% [markdown]
# Podemos filtrar las imágenes pasándole un filtro. Vamos a quedarnos con las imágenes que sean Ubuntu 20.04

# %%
filters = {"distribution": "ubuntu", "version": "20.04"}
images = glance.images.list(filters=filters)

# Vamos a listar las imágenes.
for image in images:
    print("-" * 90)
    print("Image ID", image.id)
    print("Image Name", image.name)
# Out:
# ------------------------------------------------------------------------------------------
# Image ID ebdbb5fa-03b3-48e0-822f-69ea86159f52
# Image Name IFCA Ubuntu 20.04 [2021-03-03]
# ------------------------------------------------------------------------------------------
# Image ID 8ad535fe-754d-41dd-9e71-4ae0a897249b
# Image Name IFCA Ubuntu 20.04 [2021-02-25]
# ------------------------------------------------------------------------------------------
# Image ID 783328b7-c38e-4ce0-80f5-3bfc2bb65269
# Image Name IFCA Ubuntu 20.04 [2021-02-24]
# ------------------------------------------------------------------------------------------
# Image ID b382fe0b-5bf2-40c7-a546-4c1e7b54e0e5
# Image Name IFCA Ubuntu 20.04 [2021-02-23]
# ------------------------------------------------------------------------------------------
# Image ID 3b90908e-26de-474f-9304-56b02bfba6a4
# Image Name IFCA Ubuntu 20.04 [2021-02-20]
# ------------------------------------------------------------------------------------------
# Image ID c8290829-54d6-4b73-9209-55cbf58af469
# Image Name IFCA Ubuntu 20.04 [2021-02-17]
# ------------------------------------------------------------------------------------------
# Image ID 2de65144-0255-4c15-ad73-f921b303e545
# Image Name IFCA Ubuntu 20.04 [2021-02-16]
# ------------------------------------------------------------------------------------------
# Image ID b544fb47-e73d-447a-8141-10ce1f30b95b
# Image Name IFCA Ubuntu 20.04 [2021-02-11]
# ------------------------------------------------------------------------------------------
# Image ID 4b4d630d-e895-4e68-8c82-64ffcb7cd135
# Image Name IFCA Ubuntu 20.04 [2021-02-08]

# %% [markdown]
# Vamos a utilizar la imagen `4b4d630d-e895-4e68-8c82-64ffcb7cd135`.

# %%
IMAGE_ID = "4b4d630d-e895-4e68-8c82-64ffcb7cd135"

# %% [markdown]
# Normalmente no es necesario hacer todos los pasos anteriores ya que deberíamos saber con anterioridad que imagen y flavor vamos a necesitar, pero es un buen ejemplo de como interactuar con el servicio a través de la API.

# %% [markdown]
# ## Creación de la máquina
# Ya tenemos la imagen (`IMAGE_ID`) y el flavor (`FLAVOR_ID`) que queremos utilizar, así que ya estamos listos para arrancar la máquina.
#
# Pero antes, tenemos que seleccionar que keypair vamos a utilizar. Podemos utilizar una ya existente:

# %%
nova.keypairs.list()
# Out:
# []

# %% [markdown]
# O crear una nueva. Al crear una nueva, el cliente de nova nos devolverá
# un objeto que contiene la llave pública y la llave privada (que deberemos guardar y utilizar más adelante para conectarnos a nuestra máquina).

# %%
keypair = nova.keypairs.create(name="test-master")

# %%
print(keypair.public_key)
# Out:
# ssh-rsa  Generated-by-Nova

# %%
print(keypair.private_key)
# Out:
# -----BEGIN RSA PRIVATE KEY-----
# MIIEpAIBAAKCAQEA5A5YFTLOAJghKThY0WaAOSxsAMUB4CfRUv/OtOEMw8V+9QJm
# BJ8DCPMI2k0pK8MJdCzD9+0cxqa4/DJ6D6Sm2QFaGhTa3JqkrDAhNpFkocsH2kra
# TVUa6QCmtmE2maX1z1KVezC3rL+459AeVADF7jqKrxbEXKLeC+1q7+jp4QokUzJl
# FmVEz1//u2AaLxxdwxn8kQv+hCw6OT/Kat4xeon1cTRQgyJylpoSD1dtM2Z6xjjl
# gJ5izcerNy+yZE2a+MojTUYKQaraZL5wVqaPkxgKRxC0YOzxzVY2PPUCecw73T/8
# ksD22gW5k8mOHC7eANbBbEWDLIMOmIDWFXjK2wIDAQABAoIBADEf2d9vGyrLmlEL
# vy4UG0i1hepAhZ/oU9HCIp+Z3qsJDsjuJFWYfwndeCm190li8NVikzADlnBAF5bT
# tLFL8VjLTsJRfbeJZDFnCLB9byTe3CkseIux6mMIbeDZXe6I7kMjcemgW+BNSCI/
# FVlY9UnUuGzwxYmC17vP/3oAPOjpYx8bDCTglNKy06WrvjbmPV2uPpqlmh/jcAAY
# k1nxu4mNprYpSRuZ69Ng7RjJwNt5sUha/QCtKPg4SixffFgwgtyD6slNQhC6NOa/
# Yq/9JOqgopXTUQEjEO1PHbPjmSiymaGyNGmKShe9rRICxk3vz5Lei5Ba/6gZhlxc
# 8EqrWKECgYEA/oiewEu+WLA8qKc3ml4+ee3x742IGFyTYQcAVPH4CNGkJlNUNDQN
# 0rSI0a08KVLjBWw9JozZj6XJ5GMc+huTfjau31z/y5594zgLKpCgi2bse9jmu7/Z
# rkJsLwrZ2NzhHXgQlNOFVvqZGr/wZAnjGTYmEPOIGSNLh5p6vOK0t9ECgYEA5V6s
# 5mum8ie9cCGSBikG3k2cUmpHHhJQxGMADcDohpJH7Z8sDTSIGFxsUAnHF8CfqVK5
# jLoG1vB6Weu1R5YNvwWyUUgGWfKd0jfPsvPaAaNNNaMZb5lnOU7jqa2A7jyA4gDM
# IwqRUKmD/7ASiP2s4tPmcwRKTF3hzHwDuqdkrusCgYEA9NT3VuLEqkyDXHrUGjFz
# CRee8x0BfuV1ggwY/pxtSBZXPeJDiZ9UeIvdW0q2Js2qv2mY/H7ZOrpvE7dehRmH
# aw0wcnvjNLo0Px6GZyAMvWp4KLy/XHMy8NLFew6F83qrMwxtbqpzhPGx2bAsjB2S
# i4qxXPbTv9JacYpfa1bqHDECgYBWm3sZvkhZY1wKfQKQROmNAy0liW+1ESFiJied
# CdxDA/UY6mNN0SoaWLulNSvx8g/XdZ8OXie6/S6VyYS3tRcXq+T7AAE18YBaIizQ
# 23bT63954031b60kXH9mUFdAnaPksnxiNtlL5dYrs6YsB+1B8NUxVMthLonWFnWq
# Aw7nZQKBgQCtrfSSBmJvVTHqrfc/SMR8ueItN54FOqJjLhYpNsg7YcivJffTF9BC
# tiw1TWmCzMT/RJ6lEl+Mt2Mnwo0FBAwHn8qy6lL+PsH4Go4Ff3JpWWm1+DUS3PiG
# QafrCcOsurPpIMpYi1A5UN5eMMEHFj5zQMq1UoMsd8KC+wYjvrIXXw==
# -----END RSA PRIVATE KEY-----

# %%
print(keypair.id, keypair.name)
# Out:
# test-master test-master

# %% [markdown]
# Con la información anterior ya podemos crear nuesta máquina:

# %%
mi_server = nova.servers.create(name="test %s" % USERNAME,
                                image=IMAGE_ID,
                                flavor=FLAVOR_ID,
                                key_name=keypair.name)
mi_server
# Out:
# <Server: test master20>

# %%
mi_server.status
# Out:
# 'BUILD'

# %%
print("Server ID:", mi_server.id)
print("Server name:", mi_server.name)
print("Server image:", mi_server.image)
# Out:
# Server ID: e0ea8912-958c-4d47-b10a-48c05ff43cec
# Server name: test master20
# Server image: {'id': '4b4d630d-e895-4e68-8c82-64ffcb7cd135', 'links': [{'href': 'https://api.cloud.ifca.es:8774/c725b18d8d0643e7b410dc5a8d9ab554/images/4b4d630d-e895-4e68-8c82-64ffcb7cd135', 'rel': 'bookmark'}]}

# %%
mi_server = nova.servers.get(mi_server.id)

# %%
while mi_server.status == "BUILD":
    time.sleep(2)
    mi_server = nova.servers.get(mi_server.id)
    
print(mi_server.status)
# Out:
# ACTIVE

# %% [markdown]
# ## Acceso a la máquina
# Normalmente para acceder a la máquina se utilizaría Secure Shell (SSH), utilizando un par de llaves (privada-pública), para ello habría que:
#
# 1. Crear un par de llaves en Nova, utilizando `nova.keypairs.create` (no hay que crear un par de claves por cada máquina, sino que podemos crear tan solo uno).
# 1. Asociar este par de claves en el momento de la creación (`nova.servers.create`), con el parámetro `keypair`.
# 1. Conectar a la nueva máquina, utilizando la llave privada que nos hemos bajado anteriormente.
#
# Las instancias creadas en el cloud del IFCA están creadas en una red privada y solo se ven las máquinas del mismo proyecto. Para poder acceder desde el exterior hace falta utilizar una IP pública.

# %% [markdown]
# ### Creación de una IP pública (flotante)
#
# De nuevo, necesitamos interactuar con el componente de red, neutron, para pedirle una IP flotante (pública)

# %%
neutron = net_client.Client(session=sess, insecure=True)

# %%
# Tenemos que indicarle que es una red externa, en el caso del IFCA
# esta es "cfdf9350-ab32-40db-ad1f-9790303d79dd"

req = {'floatingip':{'floating_network_id': "cfdf9350-ab32-40db-ad1f-9790303d79dd"}}

ip = neutron.create_floatingip(req)

# %%
ip["floatingip"]["floating_ip_address"]
# Out:
# '193.146.75.234'

# %%
mi_server.add_floating_ip(ip["floatingip"]["floating_ip_address"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-151c4c3bc6b6> in <module>()
# ----> 1 mi_server.add_floating_ip(ip["floatingip"]["floating_ip_address"])
#
# ~/.local/lib/python3.6/site-packages/novaclient/base.py in __getattr__(self, k)
#     174                 return self.__getattr__(k)
#     175
# --> 176             raise AttributeError(k)
#     177         else:
#     178             return self.__dict__[k]
#
# AttributeError: add_floating_ip

# %% [markdown]
# > **⚠ CUIDADO ⚠**
# > Las librerías de OpenStack son de bajo nivel. Entre diferentes versiones puede haber cambios, que aunque estén documentados, no sea compatibles o rompan la funcionalidad. En este caso, la acción `add_floating_ip` ha sido eliminada y en su lugar debemos hacer una serie de acciones de más bajo nivel: crear un puerto, asignar una IP al puerto, asignar el puerto a la máquina, etc.
# >
# > La mejor opción, cuando estemos desarrollando aplicaciones en el Cloud es utilizar el SDK de OpenStack

# %% [markdown]
# # OpenStack SDK
#
# ## Importando módulos

# %%
import openstack

# %% [markdown]
# ## Creando conexión
#
# Podemos crear una [conexión al Cloud](https://docs.openstack.org/openstacksdk/latest/user/guides/connect_from_config.html) que queramos de tres maneras diferentes.
#
# 1. Utilizando variables de entorno.
# 2. Utilizando un [Fichero de configuración](https://docs.openstack.org/openstacksdk/latest/user/guides/connect_from_config.html) basado en YAML.
#
#         clouds:
#           test_cloud:
#             region_name: RegionOne
#             auth:
#               auth_url: http://xxx.xxx.xxx.xxx:5000/v2.0/
#               username: demo
#               password: secrete
#               project_name: demo
#           ifca:
#             cloud: rackspace
#             auth:
#               auth_url: https://api.cloud.ifca.es:5000/v3/
#               username: joe
#               password: joes-password
#               project_name: 123123
#         region_name: IAD
#
# 3. Creando la conexión explícitamente:

# %%
conn = openstack.connect(
    auth_url=AUTH_URL,
    username=USERNAME,
    user_domain_name=DOMAIN,
    password=PASSWORD,
    project_id=PROJECT_ID,
    app_name='examples',
    app_version='1.0',
)
openstack.enable_logging()

# %% [markdown]
# Una vez obtenida la conexión podemos utilizar la API de alto nivel:

# %%
for server in conn.list_servers():
    print("-" * 90)
    print("Server ID:", server.id)
    print("Server name:", server.name)
# Out:
# ------------------------------------------------------------------------------------------
# Server ID: e0ea8912-958c-4d47-b10a-48c05ff43cec
# Server name: test master20
# ------------------------------------------------------------------------------------------
# Server ID: 95605d58-5479-4552-88d5-f0c50772229f
# Server name: jorgej2
# ------------------------------------------------------------------------------------------
# Server ID: 8814ba5d-013f-4d65-989f-8d734fb99e9d
# Server name: Cabrillo_Hadoop
# ------------------------------------------------------------------------------------------
# Server ID: 55804695-a047-40f0-8c76-d033445f8215
# Server name: master04
# ------------------------------------------------------------------------------------------
# Server ID: ce3ee895-c826-42aa-a30b-0751ec798ded
# Server name: master03
# ------------------------------------------------------------------------------------------
# Server ID: 29921dc0-9848-4daa-96b9-f156fcc7b79b
# Server name: Master02
# ------------------------------------------------------------------------------------------
# Server ID: 428e5bfb-0c83-4c42-9231-6a0c8ba5d6e7
# Server name: Nodo_de_Login

# %% [markdown]
# O bien la API de bajo nivel, componente a componente:

# %%
for server in conn.compute.servers():
    print("-" * 90)
    print("Server ID:", server.id)
    print("Server name:", server.name)
# Out:
# ------------------------------------------------------------------------------------------
# Server ID: e0ea8912-958c-4d47-b10a-48c05ff43cec
# Server name: test master20
# ------------------------------------------------------------------------------------------
# Server ID: 95605d58-5479-4552-88d5-f0c50772229f
# Server name: jorgej2
# ------------------------------------------------------------------------------------------
# Server ID: 8814ba5d-013f-4d65-989f-8d734fb99e9d
# Server name: Cabrillo_Hadoop
# ------------------------------------------------------------------------------------------
# Server ID: 55804695-a047-40f0-8c76-d033445f8215
# Server name: master04
# ------------------------------------------------------------------------------------------
# Server ID: ce3ee895-c826-42aa-a30b-0751ec798ded
# Server name: master03
# ------------------------------------------------------------------------------------------
# Server ID: 29921dc0-9848-4daa-96b9-f156fcc7b79b
# Server name: Master02
# ------------------------------------------------------------------------------------------
# Server ID: 428e5bfb-0c83-4c42-9231-6a0c8ba5d6e7
# Server name: Nodo_de_Login
